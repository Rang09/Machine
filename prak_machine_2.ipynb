# %% [markdown]
# <a href="https://colab.research.google.com/github/Rang09/Machine/blob/main/prak_machine_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from google.colab import files
uploaded = files.upload()
# Memuat Dataset
df = pd.read_csv('train.csv')
df.head()
# Out:
#      <input type="file" id="files-3eeeeb7e-138b-4f16-bd04-12da0e2a1298" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3eeeeb7e-138b-4f16-bd04-12da0e2a1298">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Memuat Dataset
df = pd.read_csv('train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Statistik Deskriptif DataFrame
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Kolom Kategori
cat_col = [col for col in df.columns if df[col].dtype == 'object']
print('Categorical columns :',cat_col)
# Kolom Numerik
num_col = [col for col in df.columns if df[col].dtype != 'object']
print('Numberical columns :' ,num_col)
# Out:
# Categorical columns : ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']
# Numberical columns : ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
df[cat_col].nunique()
# Out:
# Name        891
# Sex           2
# Ticket      681
# Cabin       147
# Embarked      3
# dtype: int64

# %%
# Menampilkan 50 Nomor dari kolom tiket
df['Ticket'].unique()[:50]
# Out:
# array(['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450',
#        '330877', '17463', '349909', '347742', '237736', 'PP 9549',
#        '113783', 'A/5. 2151', '347082', '350406', '248706', '382652',
#        '244373', '345763', '2649', '239865', '248698', '330923', '113788',
#        '347077', '2631', '19950', '330959', '349216', 'PC 17601',
#        'PC 17569', '335677', 'C.A. 24579', 'PC 17604', '113789', '2677',
#        'A./5. 2152', '345764', '2651', '7546', '11668', '349253',
#        'SC/Paris 2123', '330958', 'S.C./A.4. 23567', '370371', '14311',
#        '2662', '349237', '3101295'], dtype=object)

# %%
df1 = df.drop(columns=['Name','Ticket'])
df1.shape
# Out:
# (891, 10)

# %%
# Menghitung nilai hilang dari kolom
round((df1.isnull().sum()/df1.shape[0])*100,2)
# Out:
# PassengerId     0.00
# Survived        0.00
# Pclass          0.00
# Sex             0.00
# Age            19.87
# SibSp           0.00
# Parch           0.00
# Fare            0.00
# Cabin          77.10
# Embarked        0.22
# dtype: float64

# %%
# Menghapus kolom 'Cabin'
df2 =df1.drop(columns='Cabin')
df2.dropna(subset=['Embarked'],axis=0, inplace=True)
df2.shape
# Out:
# (889, 9)

# %%
# Mengimputasi
df3 = df2.fillna(df2.Age.mean())
# Memeriksa kembali nilai null
df3.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
import matplotlib.pyplot as plt

plt.boxplot(df3["Age"], vert=False)
plt.ylabel('variable')
plt.xlabel('Age')
plt.title('Box Plot')
plt.show()

# %%
X =df3[['Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']]
Y =df3['Survived']

# %%
# Menentukan nilai statistik
mean = df3['Age'].mean()
std = df3['Age'].std()

# Menghitung batas bawah dan atas
lower_bound = mean - std*2
upper_bound = mean + std*2

# Mencetak batas bawah dan atas
print('Lower Bound : ',lower_bound)
print('Upper Bound : ',upper_bound)

# Menghapus data outler
df4 = df3[(df3['Age'] >= lower_bound)
                  & (df3['Age'] <= upper_bound)]
# Out:
# Lower Bound :  3.7054001079256587
# Upper Bound :  55.57878528533277

# %%
# Membuat dua variabel baru X dan Y
X = df3[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']]
Y = df3['Survived']

# %%
from sklearn.preprocessing import MinMaxScaler

# Install MinmaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

# Kolom Numerik
num_col_ = [col for col in X.columns if X[col].dtype != 'object']
x1 = X
# mempelajari statistik setiap data
x1[num_col_] = scaler.fit_transform(x1[num_col_])
x1.head()
# Out:
# <ipython-input-74-5a2b9c0f7742>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x1[num_col_] = scaler.fit_transform(x1[num_col_])
#    Pclass     Sex       Age  SibSp  Parch      Fare Embarked
# 0     1.0    male  0.271174  0.125    0.0  0.014151        S
# 1     0.0  female  0.472229  0.125    0.0  0.139136        C
# 2     1.0  female  0.321438  0.000    0.0  0.015469        S
# 3     0.0  female  0.434531  0.125    0.0  0.103644        S
# 4     1.0    male  0.434531  0.000    0.0  0.015713        S

# %%
# Mengimpor modul yang akan digunakan
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8ab7d93f-93fa-4254-85fb-732abde65098" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8ab7d93f-93fa-4254-85fb-732abde65098">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Memuat Dataset
data = pd.read_csv('creditcard.csv')
# Mencetak info kolom di dataframe
print(data)
# Out:
#      Time        V1        V2        V3        V4        V5        V6  \
# 0       0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1       0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ..    ...       ...       ...       ...       ...       ...       ...
# 994   751  1.284612  0.303073 -0.067909  0.930684  0.117387 -0.487005
# 995   751 -0.654892  0.608319  1.585102 -3.009429  0.037593 -1.954023
# 996   752 -2.101171 -0.227365  1.624668 -0.291123  1.902446 -1.483921
# 997   753 -1.248163  0.315246  3.708935  0.687280 -0.873071  1.091287
# 998   755  1.374134 -1.767210 -0.433352 -2.229552  0.331135  3.924775
#
#            V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
# Mencetak info dataframe
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    999 non-null    int64
#  1   V1      999 non-null    float64
#  2   V2      999 non-null    float64
#  3   V3      999 non-null    float64
#  4   V4      999 non-null    float64
#  5   V5      999 non-null    float64
#  6   V6      999 non-null    float64
#  7   V7      999 non-null    float64
#  8   V8      999 non-null    float64
#  9   V9      999 non-null    float64
#  10  V10     999 non-null    float64
#  11  V11     999 non-null    float64
#  12  V12     999 non-null    float64
#  13  V13     999 non-null    float64
#  14  V14     999 non-null    float64
#  15  V15     999 non-null    float64
#  16  V16     999 non-null    float64
#  17  V17     999 non-null    float64
#  18  V18     999 non-null    float64
#  19  V19     999 non-null    float64
# ...

# %%
# mengahpus Kolom 'Time' dan 'Amount'
data = data.drop(['Time', 'Amount'], axis = 1)
#As you can observe, there are 492 fraudulent transactions
data['Class'].value_counts()
# Out:
# 0    997
# 1      2
# Name: Class, dtype: int64

# %%
from sklearn.model_selection import train_test_split

#split 70:30 ration
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state=0)

# Menjelaskan info train dan test set
print("Number transactions X_train dataset: ", X_train.shape)
print("Number transactions y_train dataset: ", Y_train.shape)
print("Number transactions X_test dataset: ", X_test.shape)
print("Number transactions y_test dataset: ", Y_test.shape)
# Out:
# Number transactions X_train dataset:  (622, 7)
# Number transactions y_train dataset:  (622,)
# Number transactions X_test dataset:  (267, 7)
# Number transactions y_test dataset:  (267,)

# %%
from sklearn.preprocessing import LabelEncoder

# Mengubah Kolom 'Sex' menjadi data numerik
label_encoder = LabelEncoder()
X_train['Sex'] = label_encoder.fit_transform(X_train['Sex'])
X_test['Sex'] = label_encoder.transform(X_test['Sex'])
# Membuaut kode one-hot pada koolom 'Embarked'
X_train = pd.get_dummies(X_train, columns=['Embarked'], drop_first=True)
X_test = pd.get_dummies(X_test, columns=['Embarked'], drop_first=True)

# %%
# Objek logistic regression
lr = LogisticRegression()

lr.fit(X_train, Y_train.ravel())

predictions = lr.predict(X_test)

# Mencetak classification report
print(classification_report(Y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.85      0.82       157
#            1       0.76      0.67      0.71       110
#
#     accuracy                           0.78       267
#    macro avg       0.78      0.76      0.77       267
# weighted avg       0.78      0.78      0.78       267

# %%
# Memanfaatkan algoritma SMOTE.
print("Before Oversampling, counts of label '1': {}".format(sum(Y_train == 1)))
print("Before Oversampling, counts of label '0': {} \n".format(sum(Y_train == 0)))

# Mengirim modul SMOTE dari imblearn library
# Install imblearn
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 2)
X_train_res, Y_train_res = sm.fit_resample(X_train, Y_train.ravel())

print('After Oversampling, the shape of train_X : {}'.format(X_train_res.shape))
print('After Oversampling, the shape of train_Y : {} \n'.format(Y_train_res.shape))

print("After Oversampling, counts of label '1': {}".format(sum(Y_train_res == 1)))
print("After Oversampling, counts of label '0': {} ".format(sum(Y_train_res== 0)))
# Out:
# Before Oversampling, counts of label '1': 230
# Before Oversampling, counts of label '0': 392
#
# After Oversampling, the shape of train_X : (784, 8)
# After Oversampling, the shape of train_Y : (784,)
#
# After Oversampling, counts of label '1': 392
# After Oversampling, counts of label '0': 392

# %%
# Objek logistic regression
lr1 = LogisticRegression()

lr1.fit(X_train_res, Y_train_res.ravel())

predictions = lr1.predict(X_test)

# Mencetak classification report
print(classification_report(Y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.77      0.79       157
#            1       0.70      0.75      0.72       110
#
#     accuracy                           0.76       267
#    macro avg       0.76      0.76      0.76       267
# weighted avg       0.77      0.76      0.77       267

# %%
# Algoritma NearMiss
print("Before Undersampling, counts of label '1': {}".format(sum(Y_train == 1)))
print("Before Undersampling, counts of label '0': {} \n".format(sum(Y_train == 0)))

#Implement NearMiss.
from imblearn.under_sampling import NearMiss
nr = NearMiss()

X_train_miss, Y_train_miss = sm.fit_resample(X_train, Y_train.ravel())

print('After Undersampling, the shape of train_X : {}'.format(X_train_miss.shape))
print('After Undersampling, the shape of train_Y : {} \n'.format(Y_train_miss.shape))

print("After Undersampling, counts of label '1': {}".format(sum(Y_train_miss == 1)))
print("After Undersampling, counts of label '0': {} ".format(sum(Y_train_miss== 0)))
# Out:
# Before Undersampling, counts of label '1': 230
# Before Undersampling, counts of label '0': 392
#
# After Undersampling, the shape of train_X : (784, 8)
# After Undersampling, the shape of train_Y : (784,)
#
# After Undersampling, counts of label '1': 392
# After Undersampling, counts of label '0': 392

# %%
# Objek logistic regression
lr2 = LogisticRegression()

lr2.fit(X_train_miss, Y_train_miss.ravel())

predictions = lr2.predict(X_test)

# Mencetak classification report
print(classification_report(Y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.77      0.79       157
#            1       0.70      0.75      0.72       110
#
#     accuracy                           0.76       267
#    macro avg       0.76      0.76      0.76       267
# weighted avg       0.77      0.76      0.77       267
